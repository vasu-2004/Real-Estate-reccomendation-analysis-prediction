# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv(r'C:\Users\vasu2.SIDHU\OneDrive\Desktop\real-estate-app\datasets\clean_data\flats_cleaned.csv')
houses = pd.read_csv(r'C:\Users\vasu2.SIDHU\OneDrive\Desktop\real-estate-app\datasets\clean_data\house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df.shape
# Out:
# (3961, 20)

# %%
df = df.sample(df.shape[0],ignore_index=True) #shuffling the data

# %%
df.head()
# Out:
#                                        property_name property_type  \
# 0                    3 BHK Flat in Sector 48 Gurgaon          flat
# 1  5 Bedroom House for sale in B Block Sushant Lo...         house
# 2                    3 BHK Flat in Sector 69 Gurgaon          flat
# 3                3 BHK Flat in Sector 1A IMT Manesar          flat
# 4                   3 BHK Flat in Sector 102 Gurgaon          flat
#
#                   society  price  price_per_sqft    area  \
# 0   parsvnath green ville   1.60          8376.0  1910.0
# 1             independent   8.25         30556.0  2700.0
# 2            tulip violet   1.65          8872.0  1860.0
# 3            deepak minda   1.20          4528.0  2650.0
# 4  emaar imperial gardens   1.98          9900.0  2000.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1910(177.44 sq.m.)Built Up...        3         3
# ...

# %%
df.to_csv(r'C:\Users\vasu2.SIDHU\OneDrive\Desktop\real-estate-app\datasets\clean_data\gurgaon_properties.csv',index=False)
